# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/DELL/Downloads/dataset.csv")

# %%
df.shape
# Out:
# (7043, 21)

# %%
len(df.columns)
# Out:
# 21

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df1 = df.drop(["customerID"], axis = 1)
df1.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
sns.heatmap(df1.corr())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22308\781785195.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr())
# <AxesSubplot:>

# %%
df1.corr()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22308\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %%
df1['Churn'].replace(to_replace='Yes', value=1, inplace=True)
df1['Churn'].replace(to_replace='No', value=0, inplace=True)
df1['SeniorCitizen'] = df['SeniorCitizen'].astype('object')

# %%
sns.countplot(x='Churn',data=df1)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %%
pd.get_dummies(df1['Churn'])
df1['Churn'].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %%
import pandas as pd

# Assuming df is your DataFrame containing the churn prediction dataset

# Separate numerical and categorical columns
numerical_columns = []
categorical_columns = []

for col in df1.columns:
    if df[col].dtype == 'object':
        categorical_columns.append(col)
    else:
        numerical_columns.append(col)

print("Numerical columns:", numerical_columns)
print("Categorical columns:", categorical_columns)
# Out:
# Numerical columns: ['SeniorCitizen', 'tenure', 'MonthlyCharges']
# Categorical columns: ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges', 'Churn']

# %%
print(df1.dtypes)

# Differentiate columns based on data types
numerical_columns = df1.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = df1.select_dtypes(include=['object']).columns

print("Numerical Columns:", numerical_columns)
print("Categorical Columns:", categorical_columns)

# Alternatively, inspect unique values for categorical distinction
for col in df1.columns:
    unique_values = df1[col].nunique()
    if unique_values < 10:  # arbitrary threshold for example
        print(f'{col} might be categorical with {unique_values} unique values')
# Out:
# gender               object
# SeniorCitizen        object
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                 int64
# dtype: object
# Numerical Columns: Index(['tenure', 'MonthlyCharges', 'Churn'], dtype='object')
# Categorical Columns: Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
# ...

# %%
import pandas as pd

# Assuming df is your DataFrame containing the churn prediction dataset

# Separate numerical and categorical columns
numerical_columns = df1.select_dtypes(include=['int', 'float']).columns
categorical_columns = df1.select_dtypes(include=['object']).columns

# Create new DataFrames for numerical and categorical features
numerical_df = df1[numerical_columns]
categorical_df = df1[categorical_columns]

# Display the first few rows of each DataFrame to verify the separation
print("Numerical DataFrame:")
print(numerical_df.head())
# Out:
# Numerical DataFrame:
#    tenure  MonthlyCharges  Churn
# 0       1           29.85      0
# 1      34           56.95      0
# 2       2           53.85      1
# 3      45           42.30      0
# 4       2           70.70      1

# %%
df_dummies = pd.get_dummies(df1)
df_dummies.head(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22308\3099161997.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   df_dummies = pd.get_dummies(df1)
#    tenure  MonthlyCharges  Churn  gender_Female  gender_Male  SeniorCitizen_0  \
# 0       1           29.85      0              1            0                1
# 1      34           56.95      0              0            1                1
# 2       2           53.85      1              0            1                1
# 3      45           42.30      0              0            1                1
# 4       2           70.70      1              1            0                1
# 5       8           99.65      1              1            0                1
# 6      22           89.10      0              0            1                1
# 7      10           29.75      0              1            0                1
# ...

# %%
df_dummies.columns
# Out:
# Index(['tenure', 'MonthlyCharges', 'Churn', 'gender_Female', 'gender_Male',
#        'SeniorCitizen_0', 'SeniorCitizen_1', 'Partner_No', 'Partner_Yes',
#        'Dependents_No',
#        ...
#        'TotalCharges_995.35', 'TotalCharges_996.45', 'TotalCharges_996.85',
#        'TotalCharges_996.95', 'TotalCharges_997.65', 'TotalCharges_997.75',
#        'TotalCharges_998.1', 'TotalCharges_999.45', 'TotalCharges_999.8',
#        'TotalCharges_999.9'],
#       dtype='object', length=6577)

# %%
len(df_dummies.columns)
# Out:
# 6577

# %%
# List of columns containing both categorical and numerical variables
columns_to_drop = ['tenure', 'MonthlyCharges', 'TotalCharges']

# Filter out only the categorical variables
categorical_columns = [col for col in columns_to_drop if col not in ['tenure', 'MonthlyCharges', 'TotalCharges']]

# Print the resulting list of categorical columns
print("Categorical Columns to Keep:", categorical_columns)
# Out:
# Categorical Columns to Keep: []

# %%
print("\nCategorical DataFrame:")
print(categorical_df.head())
# Out:
# Categorical DataFrame:
#    gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female             0     Yes         No           No  No phone service
# 1    Male             0      No         No          Yes                No
# 2    Male             0      No         No          Yes                No
# 3    Male             0      No         No           No  No phone service
# 4  Female             0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
df_dummies
# Out:
#       tenure  MonthlyCharges  Churn  gender_Female  gender_Male  \
# 0          1           29.85      0              1            0
# 1         34           56.95      0              0            1
# 2          2           53.85      1              0            1
# 3         45           42.30      0              0            1
# 4          2           70.70      1              1            0
# ...      ...             ...    ...            ...          ...
# 7038      24           84.80      0              0            1
# 7039      72          103.20      0              1            0
# 7040      11           29.60      0              1            0
# 7041       4           74.40      1              0            1
# 7042      66          105.65      0              0            1
#
#       SeniorCitizen_0  SeniorCitizen_1  Partner_No  Partner_Yes  \
# 0                   1                0           0            1
# 1                   1                0           1            0
# ...

# %%
len(df_dummies.columns)
# Out:
# 6577

# %%
df_dummies.columns
# Out:
# Index(['tenure', 'MonthlyCharges', 'Churn', 'gender_Female', 'gender_Male',
#        'SeniorCitizen_0', 'SeniorCitizen_1', 'Partner_No', 'Partner_Yes',
#        'Dependents_No',
#        ...
#        'TotalCharges_995.35', 'TotalCharges_996.45', 'TotalCharges_996.85',
#        'TotalCharges_996.95', 'TotalCharges_997.65', 'TotalCharges_997.75',
#        'TotalCharges_998.1', 'TotalCharges_999.45', 'TotalCharges_999.8',
#        'TotalCharges_999.9'],
#       dtype='object', length=6577)

# %%
ax = sns.countplot(x="Contract", data=df)

# %%
text= """math application using langchain agent:
https://towardsdatascience.com/building-a-math-application-with-langchain-agents-23919d09a4d3
 
rag with hugging face:
https://medium.com/@akriti.upadhyay/implementing-rag-with-langchain-and-hugging-face-28e3ea66c5f7
 
gene ia, llms, hugging face, openai,langchain:
https://medium.com/@chenycy/explore-generative-ai-and-llm-unveiling-hugging-face-openais-gpt-and-langchain-9bc03071a628
 
langchain book:
1.https://www.pinecone.io/learn/series/langchain/
2.https://medium.com/@okanyenigun
 
types of langchain agents:
https://www.c-sharpcorner.com/article/agents-in-langchain/
 
langchain memory:
1.https://lancerninja.com/conversational-memory-in-langchain/
2.https://www.comet.com/site/blog/enhance-conversational-agents-with-langchain-memory/
 
langchian_agent to solve the math expression:
https://medium.com/@vinusebastianthomas/langchain-agents-unleashing-the-power-of-language-models-for-real-world-automation-d4a75845717f
 
langchain agent to use file ops with minio:
https://blog.min.io/minio-langchain-tool/
 
chat_models_capabilities table:
https://python.langchain.com/docs/integrations/chat/
 
langchain agen+anthropi llm:
https://medium.com/@dminhk/langchain-%EF%B8%8F-tool-calling-and-tool-calling-agent-with-anthropic-467b0fb58980
 
combining chain and agent as chains (PAL) age, gift and budget recommender:
https://towardsdatascience.com/a-gentle-intro-to-chaining-llms-agents-and-utils-via-langchain-16cd385fca81
 
adding memory to custom agents:
https://python.langchain.com/docs/modules/agents/how_to/custom_agent/
 
langchain+prompting:
1.https://www.datacamp.com/tutorial/prompt-engineering-with-langchain
2.https://jayant017.medium.com/efficient-few-shot-prompting-in-langchain-part-1-b9b60f9c8f69
3.https://blog.gopenai.com/zeroshot-fewshot-and-prompt-chaining-using-langchain-4259d700d67f (zero+few shot)
 
langchain chains:
1.https://python.plainenglish.io/langchain-routers-a6ad9a4f2ed9
2.https://www.analyticsvidhya.com/blog/2023/10/a-comprehensive-guide-to-using-chains-in-langchain/
 
RAG:
1.https://www.analyticsvidhya.com/blog/2023/11/rag-langchain-and-vector-databases/"""

# %%
lines=text.split('\n')
links=[]
for line in lines:
    if 'http' in line:
        links.append(line)
    
print(f'the nof links:{len(links)}')
links='\n'.join(links)    
print(f"the links are: \n{links}")
# Out:
# the nof links:20
# the links are:
# https://towardsdatascience.com/building-a-math-application-with-langchain-agents-23919d09a4d3
# https://medium.com/@akriti.upadhyay/implementing-rag-with-langchain-and-hugging-face-28e3ea66c5f7
# https://medium.com/@chenycy/explore-generative-ai-and-llm-unveiling-hugging-face-openais-gpt-and-langchain-9bc03071a628
# 1.https://www.pinecone.io/learn/series/langchain/
# 2.https://medium.com/@okanyenigun
# https://www.c-sharpcorner.com/article/agents-in-langchain/
# 1.https://lancerninja.com/conversational-memory-in-langchain/
# 2.https://www.comet.com/site/blog/enhance-conversational-agents-with-langchain-memory/
# https://medium.com/@vinusebastianthomas/langchain-agents-unleashing-the-power-of-language-models-for-real-world-automation-d4a75845717f
# https://blog.min.io/minio-langchain-tool/
# https://python.langchain.com/docs/integrations/chat/
# ...
